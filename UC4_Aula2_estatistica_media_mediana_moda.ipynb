# %% [markdown]
# <a href="https://colab.research.google.com/github/raimundosena92/Corso_SenacIA_Inteligencia-Artificial/blob/main/UC4_Aula2_estatistica_media_mediana_moda.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Aula 2 – Média, Mediana, Moda e Média Ponderada
#
# ## UC4 – Estatística aplicada à Inteligência Artificial
#
# ### Objetivos da aula
# - Conceituar com clareza média, mediana, moda e média ponderada
# - Entender quando cada medida faz mais sentido
# - Comparar as medidas em diferentes contextos
# - Resolver muitos exercícios, do básico ao aplicado
# - Relacionar essas medidas com análise de dados e Inteligência Artificial

# %% [markdown]
# ## Roteiro da aula
#
# 1. Revisão rápida: o que é uma medida de tendência central
# 2. Média aritmética simples
# 3. Mediana
# 4. Moda
# 5. Média ponderada
# 6. Comparação entre as medidas
# 7. Efeito dos valores extremos
# 8. Exemplos aplicados
# 9. Lista grande de exercícios
# 10. Desafio final

# %% [markdown]
# ## 1. O que são medidas de tendência central?
#
# Medidas de tendência central são valores que tentam representar o "centro" de um conjunto de dados.
#
# Elas ajudam a resumir informações.
#
# Exemplos:
# - qual é a nota típica de uma turma?
# - qual é o salário típico de um grupo?
# - qual tamanho de camiseta aparece com mais frequência?
# - qual foi, em média, a quantidade vendida por dia?
#
# As principais medidas de tendência central são:
# - **média**
# - **mediana**
# - **moda**
#
# Nesta aula, também veremos a **média ponderada**, que é muito importante em contextos escolares, indicadores e análise de dados.

# %%
# media winsorized -> substituo o numero discrepante e substituo pelo segundo maior
salarios = [2000, 2000, 5000, 20000, 100000]
salarios2 = [2000, 2000, 5000, 20000, 20000]
media1 = sum(salarios)/len(salarios)
media2 = sum(salarios2)/len(salarios2)
print(media1)
media2  # pode ou nao ter o print
# Out:
# 25800.0
# 9800.0

# %% [markdown]
# Outras médias: Geométrica, Harmônica, Trunca, Ponto Médio e Winsorized.

# %% [markdown]
# ## 2. Média aritmética simples
#
# A média aritmética simples é a soma de todos os valores dividida pela quantidade de valores.
#
# ### Fórmula
#
# $$
# \bar{x} = \frac{x_1 + x_2 + x_3 + \dots + x_n}{n}
# $$
#
# ### Ideia intuitiva
# A média tenta "equilibrar" os dados.

# %% [markdown]
# ### Exemplo 1
# Notas: 6, 8 e 10
#
# $$
# \text{média} = \frac{6 + 8 + 10}{3} = \frac{24}{3} = 8
# $$
#
# Logo, a média é 8.

# %%
#cALCULANDO MÉDIA COM PYTHON
notas = [6, 8, 10]
media = sum(notas) / len(notas)
media
# Out:
# 8.0

# %%
#cALCULANDO MÉDIA COM NUMPY
import numpy as np

media_numpy = np.mean(notas)
media_numpy
# Out:
# np.float64(8.0)

# %%
#cALCULANDO MÉDIA COM STATISTICS
import statistics

media_statistics = statistics.mean(notas)
media_statistics
# Out:
# 8

# %% [markdown]
# ### Exemplo 2
# Idades: 18, 20, 22, 24, 26
#
# $$
# \text{média} = \frac{18+20+22+24+26}{5} = \frac{110}{5} = 22
# $$
#
# A média é 22.

# %% [markdown]
# ### Quando a média é útil?
# A média é útil quando queremos um valor representativo geral e quando os dados não têm valores extremos muito distorcidos.

# %% [markdown]
# ### Exercício
#
# Calcule a média aritmética do "EXEMPLO 2" utilizando python, numpy e statistics

# %%
# media com Python
idades = [18, 20, 22, 24, 26]
media = sum(idades) / len(idades)
media
# Out:
# 22.0

# %%
# media com numpy
import numpy as np

idades = [18, 20, 22, 24, 26]
media_numpy = np.mean(idades)
media_numpy
# Out:
# np.float64(22.0)

# %%
#media com statistics
import statistics

idades = [18, 20, 22, 24, 26]
media_statistics  = statistics.mean(idades)
media_statistics
# Out:
# 22

# %% [markdown]
# ## 3. Mediana
#
# A mediana é o valor que fica no meio dos dados **depois que eles são colocados em ordem**.

# %% [markdown]
# ### Passo a passo
# 1. Ordenar os dados
# 2. Verificar a quantidade de elementos
# 3. Encontrar o valor central
#
# ### Caso 1: quantidade ímpar de dados
# Exemplo: 3, 5, 8, 10, 12
#
# O valor do meio é 8.
# Logo, a mediana é 8.
#
# ### Caso 2: quantidade par de dados
# Exemplo: 4, 6, 8, 10
#
# Os dois valores centrais são 6 e 8.
# A mediana será a média entre eles:
#
# $$
# \text{mediana} = \frac{6+8}{2}=7
# $$

# %%
dados = [10, 6, 8, 4]
dados_ordenados = sorted(dados)
dados_ordenados = [4, 6, 8, 10]
dados_ordenados
# Out:
# [4, 6, 8, 10]

# %%
mediana = statistics.median(dados)
mediana
# Out:
# 7.0

# %%
mediana = np.median(dados)
mediana
# Out:
# np.float64(7.0)

# %% [markdown]
# ### Fórmula para encontrar a média quando o número de elementos (n) é impar:
#
#
# $$Md ={\left(\frac{n+1}{2}\right)}$$

# %% [markdown]
# ### Fórmula para encontrar a média quando o número de elementos (n) é par:
#
# $$Md = \frac{{\left(\frac{n}{2}\right)} + {\left(\frac{n}{2} + 1\right)}}{2}$$

# %% [markdown]
# ### Exercício:
#
# Crie um código python para calcular a mediana (sem utilizar bibliotecas externas, como numpy, stati, etc)
#
# dica: para ordenar os dados, utilize ``dados ordenados = sorted(dados)``

# %%
# MEDIA ARITMETICA
dados_ordenados = [20 , 10, 14, 15, 25, 12 ]
dados_ordenados.sort()

media = sum(dados_ordenados) / len(dados_ordenados)
media
# Out:
# 16.0

# %%
lista = [20 , 10, 14, 15, 25, 12 ]

lista_ordenada = sorted(lista)  # ordenando lista
lista_ordenada
# Out:
# [10, 12, 14, 15, 20, 25]

# %%
n = len(lista_ordenada)  # contando a quantidade de itens da lista
n
# Out:
# 6

# %%
# Mediana
mediana = statistics.median(lista_ordenada)
mediana
# Out:
# 14.5

# %%
dados = [1,5,7,2,3,4,1]
def calcular_mediana(dados):
  dados_ordenados = sorted(dados)  #aqui ordeno os dados da lista
  n = len(dados_ordenados)     #  aqui estou contando os quantidade de numero da lista
  if n == 0:
   return None
  if n % 2 != 0:   # para numero impar
    mediana = dados_ordenados[n//2]
  else:    # para numero par
    indice2 = n//2
    indice1 = indice2 - 1
    mediana = (dados_ordenados[indice1] + dados_ordenados[indice2]) / 2
  return mediana

# %%
# dados impares
dados = [5,7,2,3,4,]

# %%
dados_ordenados = sorted(dados)  # sorted =comando para ordenar os dados
dados_ordenados                  # dados impares -> medidana = 4 que e o numero do centro
# Out:
# [2, 3, 4, 5, 7]

# %%
n = len(dados_ordenados)  # e o comando que conta a qtde iteens do conjunto de dados
n
# Out:
# 5

# %%
mediana = dados_ordenados[n//2]
mediana
# Out:
# 4

# %%
# dados pares
dados = [5,7,2,3,4,6]

# %%
dados_ordenados = sorted(dados)  # primeiro ordeno
dados_ordenados
# Out:
# [2, 3, 4, 5, 6, 7]

# %%
n = len(dados_ordenados)   # conto os dados se impar ou par
n
# Out:
# 6

# %%
mediana = (dados_ordenados[n//2] + dados_ordenados[n//2 - 1]) / 2
mediana
# Out:
# 4.5

# %%
mediana = statistics.median(dados_ordenados)
mediana
# Out:
# 4.5

# %%
mediana = np.median(dados_ordenados)
mediana
# Out:
# np.float64(4.5)

# %%
# feito pelo  professor
# para numero impar
def calcular_mediana(dados):
  dados_ordenados = sorted(dados)  #aqui ordeno os dados da lista
  n = len(dados_ordenados)     #  aqui estou contando a quantidade de numero da lista
  if n == 0:
   return None
  if n % 2 != 0:   # para numero impar
    meio = n//2   # // considera so o numero inteiro, desconsidero o decimal (3,5) considero so o 3
    mediana = dados_ordenados[meio]
  else:    # para numero par
    indice2 = n//2
    indice1 = indice2 - 1
    mediana = (dados_ordenados[indice1] + dados_ordenados[indice2]) / 2
  return mediana

# %%
lista1 = [7,9,8,4]

# %%
lista1.sort()
lista1
# Out:
# [4, 7, 8, 9]

# %%
calcular_mediana(lista1)
# Out:
# 7.5

# %%
mediana = statistics.median(lista1)
mediana
# Out:
# 7.5

# %%
mediana = np.median(lista1)
mediana
# Out:
# np.float64(7.5)

# %%
lista2 = [-1,10,13,4,5]

# %%
calcular_mediana(lista2)
# Out:
# 5

# %%
lista2.sort()
lista2
# Out:
# [-1, 4, 5, 10, 13]

# %%
# Utilizando o numpy
mediana01 = np.median(lista1)
mediana01
# Out:
# np.float64(7.5)

# %%
mediana02 = np.median(lista2)
mediana02
# Out:
# np.float64(5.0)

# %%
#Utilizando o statistics
mediana_lista01 = statistics.median(lista1)
mediana_lista01
# Out:
# 7.5

# %%
mediana_lista02 = statistics.median(lista2)
mediana_lista02
# Out:
# 5

# %% [markdown]
# ### Por que a mediana é importante?
# A mediana é muito útil quando há valores extremos.
#
# Exemplo:
# Salários: 1800, 1900, 2000, 2100, 50000
#
# A média sobe muito por causa do 50000, mas a mediana continua mais próxima da realidade do grupo.

# %%
dados = [1800, 1900, 2000, 2100, 50000]
mediana = np.median(dados)
mediana
# Out:
# np.float64(2000.0)

# %% [markdown]
# ## 4. Moda
#
# A moda é o valor que mais se repete.
#
# ### Exemplos
#
# - Dados: 2, 3, 3, 5, 8
#   Moda = 3
#
# - Dados: azul, azul, verde, vermelho, azul
#   Moda = azul
#
# A moda é a única das medidas de tendência central que pode ser aplicada facilmente também em dados qualitativos.
#
# ### Observações importantes
# - um conjunto pode ter **uma moda**: unimodal
# - pode ter **duas modas**: bimodal
# - pode ter **mais de duas modas**: multimodal
# - pode **não ter moda**, se nenhum valor repetir

# %%
from collections import Counter  # pega uma lista e transforma em dicionario
dados = [2, 3, 3, 5, 8]
contagem = Counter(dados)

# %%
contagem
# Out:
# Counter({2: 1, 3: 2, 5: 1, 8: 1})

# %%
contagem.most_common(1)   # mostra a contagem mais comum = MODA
# Out:
# [(3, 2)]

# %%
dados2 = [2, 3, 3, 5, 8, 8]
contagem2 = Counter(dados2)
contagem2
# Out:
# Counter({2: 1, 3: 2, 5: 1, 8: 2})

# %%
moda = statistics.mode(dados)
moda
# Out:
# 3

# %%
moda2 = statistics.mode(dados2)
moda2
# Out:
# 3

# %%
moda2 = statistics.multimode(dados2)
moda2
# Out:
# [3, 8]

# %%
dados_str = ['a', 'b', 'c', 'a']

# %%
moda_str = statistics.mode(dados_str )
moda_str
# Out:
# 'a'

# %%
contagem_str = Counter(dados_str)
contagem_str
# Out:
# Counter({'a': 2, 'b': 1, 'c': 1})

# %% [markdown]
# ### Exemplo de moda em dados qualitativos
# Categorias de produto:
# - eletrônico
# - eletrônico
# - acessório
# - acessório
# - acessório
#
# Moda = acessório

# %%
dados = ['eletronico', 'eletronico', 'acessorio', 'acessorio', 'acessorio']
moda = statistics.mode(dados)
moda
# Out:
# 'acessorio'

# %%
contagem_str = Counter(dados)
contagem_str
# Out:
# Counter({'eletronico': 2, 'acessorio': 3})

# %% [markdown]
# ## 5. Média ponderada
#
# Na média simples, todos os valores têm o mesmo peso.
#
# Na média ponderada, alguns valores valem mais do que outros.
#
# ### Fórmula
#
# $$
# \text{média ponderada} = \frac{x_1p_1 + x_2p_2 + x_3p_3 + \dots + x_np_n}{p_1+p_2+p_3+\dots+p_n}
# $$
#
# onde:
# - \(x\) são os valores
# - \(p\) são os pesos
#
# ### Exemplo 1: notas com pesos diferentes
# Um aluno tirou:
# - Prova 1 = 7, peso 2
# - Prova 2 = 9, peso 3
#
# $$
# \text{média ponderada} = \frac{7 \cdot 2 + 9 \cdot 3}{2+3}
# = \frac{14+27}{5}
# = \frac{41}{5}
# = 8,2
# $$
#
# Logo, a média ponderada é 8,2.

# %%
notas = [7, 9]
pesos = [2, 3]

media_ponderada = sum(n*p for n, p in zip(notas, pesos)) / sum(pesos)  # zip junta os dados dos conjuntos de dados
media_ponderada
# Out:
# 8.2

# %%
media_ponderada = np.average(notas, weights=pesos)  # average = media
media_ponderada
# Out:
# np.float64(8.2)

# %%
import numpy as np

notas = [7, 9]
pesos = [2, 3]

media_ponderada = np.average(notas, weights=pesos)
print(media_ponderada)
# Out:
# 8.2

# %%
import statistics

# Cria uma lista onde o 7 aparece 2 vezes e o 9 aparece 3 vezes = forma expandida
dados_expandidos = [7, 7, 9, 9, 9]
media = statistics.mean(dados_expandidos)
print(media )
#Aqui tem uma observação importante
# Out:
# 8.2

# %%
media = sum(dados_expandidos)/len(dados_expandidos)
print(media)
#
# Out:
# 8.2

# %%
media = np.average(dados_expandidos)
print(media)
#
# Out:
# 8.2

# %% [markdown]
# ### Exemplo 2: média ponderada em compras
# Um produto foi vendido assim:
# - 10 unidades a R\$ 5
# - 30 unidades a R\$ 8
#
# O preço médio ponderado por quantidade é:
#
# $$
# \frac{10 \cdot 5 + 30 \cdot 8}{10+30}
# =
# \frac{50+240}{40}
# =
# \frac{290}{40}
# =
# 7,25
# $$
#
# O valor 7,25 representa melhor o preço médio real das vendas do que uma média simples entre 5 e 8.

# %%
precos = [5, 8]
quantidades = [10, 30]

media_ponderada = sum(p*q for p, q in zip(precos, quantidades)) / sum(quantidades)
media_ponderada
# Out:
# 7.25

# %%
media_ponderada = np.average(precos, weights=quantidades)
media_ponderada
# Out:
# np.float64(7.25)

# %% [markdown]
# ## 6. Comparando as medidas
#
# | Medida | Ideia principal | Ponto forte | Limitação |
# |---|---|---|---|
# | Média | equilíbrio dos dados | usa todos os valores | sensível a extremos |
# | Mediana | valor central | resiste a outliers | não usa a intensidade completa dos dados |
# | Moda | valor mais frequente | útil em categorias | pode não existir ou haver várias |
# | Média ponderada | média com pesos diferentes | mais realista em muitos contextos | exige pesos corretos |
#
# ### Regra prática
# - use **média** quando os dados forem relativamente equilibrados
# - use **mediana** quando houver valores extremos
# - use **moda** para descobrir o valor mais comum
# - use **média ponderada** quando os valores tiverem importâncias diferentes

# %% [markdown]
# ## 7. Efeito dos valores extremos
#
# Vamos comparar dois conjuntos:
#
# ### Conjunto A
# 10, 12, 13, 14, 16
#
# ### Conjunto B
# 10, 12, 13, 14, 100
#
# Ambos têm vários valores parecidos, mas o segundo tem um valor extremo.

# %%
conjunto_a = [10, 12, 13, 14, 16]
conjunto_b = [10, 12, 13, 14, 100]

resultado = {
    "media_A": sum(conjunto_a)/len(conjunto_a),
    "mediana_A": np.median(conjunto_a),
    "media_B": sum(conjunto_b)/len(conjunto_b),
    "mediana_B": np.median(conjunto_b),
}
resultado
# Out:
# {'media_A': 13.0,
#  'mediana_A': np.float64(13.0),
#  'media_B': 29.8,
#  'mediana_B': np.float64(13.0)}

# %% [markdown]
# ### Conclusão
# No conjunto B, a média sobe bastante por causa do valor 100, mas a mediana permanece mais estável.
#
# Isso mostra por que a mediana é tão importante em dados com outliers.

# %% [markdown]
# ## 8. Aplicações em IA e análise de dados
#
# Essas medidas aparecem em várias tarefas:
#
# ### Média
# - média de notas
# - média de vendas
# - média de tempo de atendimento
# - média de erro de um modelo
#
# ### Mediana
# - valor típico quando há outliers
# - análise de salários
# - tempo de resposta de sistemas
# - limpeza de dados
#
# ### Moda
# - categoria mais frequente
# - classe mais comum
# - produto mais vendido
# - valor usado em preenchimento de dados categóricos faltantes
#
# ### Média ponderada
# - nota final com pesos
# - indicadores compostos
# - métricas combinadas
# - média de preços por volume

# %% [markdown]
# # Exercícios resolvidos
#
# ## Exercício resolvido 1
# Calcule a média de 4, 6, 8, 10
#
# $$
# \text{média} = \frac{4+6+8+10}{4} = \frac{28}{4} = 7
# $$

# %%
dados = [4, 6, 8, 10]
sum(dados)/len(dados)
# Out:
# 7.0

# %%
media = np.mean(dados)
media
# Out:
# np.float64(7.0)

# %%
media = statistics.mean(dados)
media
# Out:
# 7

# %% [markdown]
# ## Exercício resolvido 2
# Calcule a mediana de 2, 5, 7, 9, 12
#
# Os dados já estão em ordem.
# O valor central é 7.
# Logo, a mediana é 7.

# %%
np.median([2, 5, 7, 9, 12])
# Out:
# np.float64(7.0)

# %%
mediana = statistics.median(dados)
mediana
# Out:
# 7.0

# %% [markdown]
# ## Exercício resolvido 3
# Calcule a moda de 1, 2, 2, 3, 4, 4, 4, 5
#
# O valor que mais repete é 4.
# Logo, a moda é 4.

# %%
mediana = np.median([1, 2, 2, 3, 4, 4, 4, 5])
mediana = statistics.mode([1, 2, 2, 3, 4, 4, 4, 5])
mediana
# Out:
# 4

# %%
dados = [1, 2, 2, 3, 4, 4, 4, 5]
contagem = Counter(dados)
contagem
# Out:
# Counter({1: 1, 2: 2, 3: 1, 4: 3, 5: 1})

# %%
moda = statistics.multimode(dados)
moda
# Out:
# [4]

# %% [markdown]
# ## Exercício resolvido 4
# Calcule a média ponderada:
# - 6 com peso 1
# - 8 com peso 2
# - 10 com peso 3
#
# $$
# \frac{6\cdot1 + 8\cdot2 + 10\cdot3}{1+2+3}
# =
# \frac{6+16+30}{6}
# =
# \frac{52}{6}
# =
# 8,67
# $$

# %%
valores = [6, 8, 10]
pesos = [1, 2, 3]

media_ponderada = sum(v*p for v, p in zip(valores, pesos)) / sum(pesos)
media_ponderada
# Out:
# 8.666666666666666

# %%
media_ponderada = np.average(valores, weights=pesos)
media_ponderada
# Out:
# np.float64(8.666666666666666)

# %% [markdown]
# # Lista de exercícios
#
# ## Parte A – Conceituação
#
# ### Exercício 1
# Explique, com suas palavras:
# - o que é média
#
# É a somados dos dados dividido pela quantidade de dados ou seja, e o ponto medio dos dados.
#
# - o que é mediana
#
# È o ponto central de um conjunto de dados. é muito usado quando no conjunto tem algum numero destoante da media (outliers).
#
# - o que é moda
#
# É o dado que mais se repete em um conjuto de dados ou seja o dado mais comum
# .
#
# - o que é média ponderada
#
# É o ponto medio de um conjunto de dados com pesos diferente
#
#
#
# ### Exercício 2
# Qual medida de tendência central costuma ser mais afetada por valores extremos? Explique.
#
# A media é a mais afetada pois devido aos outliers o valor difere muito da media real.
#
# ### Exercício 3
# Em que situação a moda é mais útil do que a média?
#
# Quando preciso saber o dado mais comum, o mais frequente, o mais vendido.
#
#
# ### Exercício 4
# Qual a diferença entre média simples e média ponderada?
#
# A media ponderada é usada quando os dados tem pesos diferente

# %% [markdown]
# ## Parte B – Cálculo direto
#
# ### Exercício 5
# Calcule a média:
# - 5, 7, 9
#
# media=(5+7+9)/3
#
# media= 21/3
#
# media=7
#
# ### Exercício 6
# Calcule a média:
# - 12, 15, 18, 21
#
# media=(12+15+18+21)/4
#
#
# media=66/4 = 16.4
#
#
# ### Exercício 7
# Calcule a mediana:
# - 3, 5, 8, 10, 12
#
# mediana=8
#
# ### Exercício 8
# Calcule a mediana:
# - 4, 6, 8, 10
#
# mediana= (6+8)/2
#
# mediana=14/2
#
# mediana= 7
#
#
# ### Exercício 9
# Calcule a moda:
# - 2, 2, 3, 4, 5
# moda= 2
#
# ### Exercício 10
# Calcule a moda:
# - 1, 3, 3, 4, 4, 6
#
# moda= (3+4)/2
# moda= 3.5
#
#
# ### Exercício 11
# Calcule média, mediana e moda:
# - 2, 4, 4, 5, 7
# media=(2+4+4+5+7)/5
#
# media=22/5
# media=4.4
#
# mediana=4
#
# moda=4
#
# ### Exercício 12
# Calcule média, mediana e moda:
# - 10, 10, 12, 15, 20
# media=(10+10+12+15+20)/5 -> media=67/5 =13.4
#
# mediana=12
#
# moda=10

# %% [markdown]
# ## Parte C – Média ponderada
#
# ### Exercício 13
# Calcule a média ponderada:
# - 7 com peso 2
# - 9 com peso 3
#
# ### Exercício 14
# Calcule a média ponderada:
# - 5 com peso 1
# - 6 com peso 2
# - 8 com peso 2
#
# ### Exercício 15
# Um aluno teve as seguintes notas:
# - trabalho = 8, peso 2
# - prova = 6, peso 5
# - projeto = 9, peso 3
#
# Calcule a média final.
#
# ### Exercício 16
# Um produto foi vendido assim:
# - 20 unidades a R$ 4
# - 10 unidades a R$ 6
# - 30 unidades a R$ 5
#
# Calcule o preço médio ponderado.

# %%
#Exercício 5
#Calcule a média:

dados = [5, 7, 9]
#media=(5+7+9)/3
#media= 21/3
#media=7
media = sum(dados)/len(dados)
print("media= ",media)
# Out:
# media=  7.0

# %%
#Exercício 6
#Calcule a média:

#12, 15, 18, 21
#media=(12+15+18+21)/4
#media=66/4 = 16.4
media = sum(dados)/len(dados)
print("media= ",media)
# Out:
# media=  4.4

# %%
#Exercício 7
#Calcule a mediana:

#3, 5, 8, 10, 12
#mediana=8
mediana = np.median([3, 5, 8, 10, 12])
print("mediana = ", mediana)
# Out:
# mediana =  8.0

# %%
#Exercício 8
#Calcule a mediana:

#4, 6, 8, 10
#mediana= (6+8)/2
#mediana=14/2
#mediana= 7
mediana= np.median([4, 6, 8, 10])
print('mediana= ', mediana)
# Out:
# mediana=  7.0

# %%
#Exercício 9
#Calcule a moda:

#2, 2, 3, 4, 5 moda= 2
moda=statistics.mode([2, 2, 3, 4, 5])
print('moda= ', moda)
# Out:
# moda=  2

# %%
#Exercício 10
#Calcule a moda:

#1, 3, 3, 4, 4, 6
#moda= (3+4)/2 moda= 3.5
moda= statistics.multimode([1, 3, 3, 4, 4, 6])
print('moda= ', moda)
# Out:
# moda=  [3, 4]

# %%
#Exercício 11
#Calcule média, mediana e moda:

dados=[2, 4, 4, 5, 7]
#media=(2+4+4+5+7)/5
#media=22/5 media=4.4
media_simples= sum(dados)/len(dados)
print("media_simples= ",media_simples)

#mediana=4
mediana = np.median(dados)
print("mediana= ",mediana)

#moda=4
moda=statistics.mode(dados)
print("moda= ",moda)
# Out:
# media_simples=  4.4
# mediana=  4.0
# moda=  4

# %%
#Exercício 12
#Calcule média, mediana e moda:

#10, 10, 12, 15, 20 media=(10+10+12+15+20)/5 -> media=67/5 =13.4
#mediana=12

#moda=10
valores=[10, 10, 12, 15, 20]
mediana = np.median(valores)
mediana
# Out:
# np.float64(12.0)

# %%
mediana= statistics.median(valores)
mediana
# Out:
# 12

# %%
#Exercício 13
#Calcule a média ponderada:

#7 com peso 2
#9 com peso 3
notas=[7,9]
pesos=[2,3]
media_pond = sum(v*p for v, p in zip(notas, pesos)) / sum(pesos)
media_pond
# Out:
# 8.2

# %%
media_pond = np.average(notas, weights=pesos)
media_pond
# Out:
# np.float64(8.2)

# %%
#Exercício 14
#Calcule a média ponderada:

#5 com peso 1
#6 com peso 2
#8 com peso 2
notas=[5,6,8]
pesos=[1,2,2]
media_pond = sum(v*p for v, p in zip(notas, pesos)) / sum(pesos)
media_pond
# Out:
# 6.6

# %%
media_pond = np.average(notas, weights=pesos)
media_pond
# Out:
# np.float64(6.6)

# %%
#Exercício 15
#Um aluno teve as seguintes notas:

#trabalho = 8, peso 2
#prova = 6, peso 5
#projeto = 9, peso 3
dados=[8, 6, 9]
pesos=[2, 5, 3]
media_pond = sum(v*p for v, p in zip(dados, pesos)) / sum(pesos)
media_pond
# Out:
# 7.3

# %%
media_pond = np.average(dados, weights=pesos)
media_pond
# Out:
# np.float64(7.3)

# %%
#Exercício 16
#Um produto foi vendido assim:

#20 unidades a R 4
#10 unidadesaR  6
#30 unidades a R$ 5
#Calcule o preço médio ponderado.
valores=[4,6,5]
pesos=[20,10,30]
media_pond = sum(v*p for v, p in zip(valores, pesos)) / sum(pesos)
media_pond
# Out:
# 4.833333333333333

# %%
media_pond = np.average(valores, weights=pesos)
media_pond
# Out:
# np.float64(4.833333333333333)

# %% [markdown]
# ## Parte D – Interpretação
#
# ### Exercício 17
# Observe os conjuntos:
# - A = 8, 9, 10, 10, 11
# - B = 8, 9, 10, 10, 100
#
# Calcule a média e a mediana de cada um.
# Depois, diga qual medida representa melhor cada conjunto.
#
# ### Exercício 18
# Uma loja registrou as categorias mais vendidas:
# - camiseta
# - camiseta
# - tênis
# - calça
# - camiseta
# - tênis
#
# Qual é a moda?
# Por que a média não faria sentido aqui?
#
# ### Exercício 19
# Explique por que a mediana pode ser melhor que a média em salários.
#
# ### Exercício 20
# Explique por que a média ponderada é mais adequada para calcular nota final quando provas têm pesos diferentes.

# %%
#Exercício 17
#Observe os conjuntos:

A = 8, 9, 10, 10, 11
B = 8, 9, 10, 10, 100
#Calcule a média e a mediana de cada um.
#Depois, diga qual medida representa melhor cada conjunto. MEDIANA, pois a media difere muito pois tem outliers.
media_A=sum(A)/len(A)
print("media_A= ",media_A)
media_B=sum(B)/len(B)
print("media_B= ",media_B)
mediana_A=np.median(A)
print("mediana_A= ",mediana_A)
mediana_B=np.median(B)
print("mediana_B= ",mediana_B)
# Out:
# media_A=  9.6
# media_B=  27.4
# mediana_A=  10.0
# mediana_B=  10.0

# %%
#Exercício 18
#Uma loja registrou as categorias mais vendidas:

#camiseta
#camiseta
#tênis
#calça
#camiseta
#tênis
#Qual é a moda?
#Por que a média não faria sentido aqui? porque nao existe media de dados qualitativo

dados=["camiseta", "camiseta", "tênis", "calça", "camiseta", "tênis"]
moda = statistics.multimode(dados)
moda
# Out:
# ['camiseta']

# %%
from collections import Counter
dados=["camiseta", "camiseta", "tênis", "calça", "camiseta", "tênis"]
contagem = Counter(dados)

# %%
contagem
# Out:
# Counter({'camiseta': 3, 'tênis': 2, 'calça': 1})

# %%
#Exercício 19
#Explique por que a mediana pode ser melhor que a média em salários. porque se tiver valores outliers a mediana sera melhor pois se aproximará mais
#da media real.

# %%
#Exercício 20
#Explique por que a média ponderada é mais adequada para calcular nota final quando provas têm pesos diferentes.
# Porque so atraves da media ponderada conseguimos avaliar dados com pesos diferente.

# %% [markdown]
# ## Parte E – Aplicação com Python
#
# Execute as células abaixo e complete as respostas.

# %%
# Base 1
notas_turma = [6, 7, 8, 8, 9, 10, 5, 8]

media = sum(notas_turma) / len(notas_turma)
mediana = np.median(notas_turma)
moda = statistics.multimode(notas_turma)

media, mediana, moda
# Out:
# (7.625, np.float64(8.0), [8])

# %%
# perguntar ao professor
moda = Counter(notas_turma).most_common()
moda
# Out:
# [(8, 3), (6, 1), (7, 1), (9, 1), (10, 1), (5, 1)]

# %% [markdown]
# ### Exercício 21
# Anote os valores de média, mediana e moda da turma acima.
#
# ### Exercício 22
# Qual medida parece representar melhor essa turma? Explique.

# %%
#Exercício 21
# Anote os valores de média, mediana e moda da turma acima.
print("media= ",media)
print("mediana= ",mediana)
print("moda= ",moda)
# Out:
# media=  7.625
# mediana=  8.0
# moda=  8

# %%
#Exercício 22
# Qual medida parece representar melhor essa turma? Explique. Mediana pq esta mais proximo da realidade

# %%
# Base 2
salarios = [1800, 2000, 2200, 2500, 3000, 50000]

media = sum(salarios) / len(salarios)
mediana = np.median(salarios)
print("media= ",media)
print("mediana= ", mediana)
# Out:
# media=  10250.0
# mediana=  2350.0

# %% [markdown]
# ### Exercício 23
# Compare média e mediana dos salários.
#
#  #A media destoa do real devido ao valor outlier
#
# ### Exercício 24
# Qual delas representa melhor o "salário típico" desse grupo?
#
#
# #MEDIANA pois represnta o valor mais proximo do real porque quando tem outlier a media foge muito do real.

# %%
# Base 3
valores = [7, 9, 6]
pesos = [2, 5, 3]

media_pond = sum(v*p for v, p in zip(valores, pesos)) / sum(pesos)
media_pond
# Out:
# 7.7

# %%
media_ponderada = np.average(valores, weights=pesos)
media_ponderada
# Out:
# np.float64(7.7)

# %% [markdown]
# ### Exercício 25
# Interprete o valor encontrado acima.
#
# A media ponderada considera os pesos de cada nota por isso a media é maior.
#
#
# ### Exercício 26
# Se todos os pesos fossem iguais, o resultado mudaria? Verifique.
#
# Se os pesos fossem iguais calculariamos a media simples = 7,3333

# %%
# Compare média simples e média ponderada
valores = [7, 9, 6]
media_simples = sum(valores) / len(valores)

pesos = [2, 5, 3]
media_ponderada = sum(v*p for v, p in zip(valores, pesos)) / sum(pesos)
print("media_ponderada = ", media_ponderada)
print("media_simples = ", media_simples)

media_simples, media_ponderada
float(media_simples)
# Out:
# media_ponderada =  7.7
# media_simples =  7.333333333333333
# 7.333333333333333

# %% [markdown]
# # Desafio final
#
# Uma escola quer resumir o desempenho de uma turma.
#
# As notas foram:
# - 4, 5, 5, 6, 6, 6, 7, 8, 20
#
# ## Tarefas
# 1. Calcule a média
# 2. Calcule a mediana
# 3. Calcule a moda
# 4. Diga qual medida representa melhor a turma
# 5. Explique por que uma delas pode ser enganosa nesse caso
#
# Depois, responda:
#
# > Se você fosse construir um sistema para analisar automaticamente notas de turmas, qual medida usaria com mais cuidado: média, mediana ou moda? Justifique.

# %%
# 1. Calcule a média
dados = [4, 5, 5, 6, 6, 6, 7, 8, 20]
media = sum(dados) / len(dados)
media
# Out:
# 7.444444444444445

# %%
# 2. Calcule a mediana
mediana = np.median(dados)
mediana
# Out:
# np.float64(6.0)

# %%
# 3. Calcule a moda
moda = statistics.mode(dados)
moda
# Out:
# 6

# %%
# 4. Diga qual medida representa melhor a turma? Mediana

# %%
# 5. Explique por que uma delas pode ser enganosa nesse caso? A media pode nao refletir o real devido ao outlier.

# %% [markdown]
# # Fechamento
#
# Nesta aula, estudamos:
# - média
# - mediana
# - moda
# - média ponderada
#
# Também vimos:
# - quando usar cada medida
# - como valores extremos afetam a média
# - por que a mediana pode ser mais adequada em certos contextos
# - como a média ponderada aparece em notas, vendas e indicadores
#
# Na próxima etapa, essas medidas servirão de base para interpretação de dados e comparação entre grupos.
